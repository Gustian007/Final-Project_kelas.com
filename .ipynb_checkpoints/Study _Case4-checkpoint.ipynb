# %%
# Data manipulation library
import pandas as pd
import os
import numpy as np

from tensorflow.keras.preprocessing import image
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import VGG16
import tensorflow as tf
from tensorflow.keras import layers

import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# Load Dataset
cat_folder = 'PetImages/Cat'  
dog_folder = 'PetImages/Dog'

# %%
# Mengumpulkan gambar dengan format jpg dan png
cat_images = [os.path.join(cat_folder, f) for f in os.listdir(cat_folder) if f.endswith(('jpg', 'png'))]
dog_images = [os.path.join(dog_folder, f) for f in os.listdir(dog_folder) if f.endswith(('jpg', 'png'))]

# %%
# membuat label
cat_labels = ['cat'] * len(cat_images)
dog_labels = ['dog'] * len(dog_images)

# %%
# Menggabungkan label dan path gambar ke dalam dataframe
image_paths = cat_images + dog_images
labels = cat_labels + dog_labels

# %%
df = pd.DataFrame({
    'image_path': image_paths,
    'label': labels
})

# %%
print(df)
# Out:
#                    image_path label
# 0         PetImages/Cat\0.jpg   cat
# 1         PetImages/Cat\1.jpg   cat
# 2        PetImages/Cat\10.jpg   cat
# 3       PetImages/Cat\100.jpg   cat
# 4      PetImages/Cat\1000.jpg   cat
# ...                       ...   ...
# 24993  PetImages/Dog\9995.jpg   dog
# 24994  PetImages/Dog\9996.jpg   dog
# 24995  PetImages/Dog\9997.jpg   dog
# 24996  PetImages/Dog\9998.jpg   dog
# 24997  PetImages/Dog\9999.jpg   dog
#
# [24998 rows x 2 columns]

# %%
print(f"Jumlah gambar CAT: {len(cat_images)}")
print(f"Jumlah gambar DOG: {len(dog_images)}")
# Out:
# Jumlah gambar CAT: 12499
# Jumlah gambar DOG: 12499

# %% [markdown]
# # Data Split

# %%
import os
import shutil
import random

# Path ke direktori utama
source_dir = 'PetImages'

# Path ke direktori train dan validation
train_dir = 'PetImages/train'
validation_dir = 'PetImages/validation'

# Membuat folder 'train' dan 'validation' jika belum ada
os.makedirs(os.path.join(train_dir, 'CAT'), exist_ok=True)
os.makedirs(os.path.join(train_dir, 'DOG'), exist_ok=True)
os.makedirs(os.path.join(validation_dir, 'CAT'), exist_ok=True)
os.makedirs(os.path.join(validation_dir, 'DOG'), exist_ok=True)

# Folder data untuk CAT dan DOG
cat_dir = os.path.join(source_dir, 'CAT')
dog_dir = os.path.join(source_dir, 'DOG')

# Fungsi untuk membagi gambar
def split_data(source_folder, train_folder, validation_folder, validation_ratio=0.2):
    
    files = os.listdir(source_folder)
    
    random.shuffle(files)
    
    num_validation = int(len(files) * validation_ratio)
    
    # Membagi file
    validation_files = files[:num_validation]
    train_files = files[num_validation:]
    
    # Memindahkan gambar ke folder yang sesuai
    for file in train_files:
        shutil.copy(os.path.join(source_folder, file), os.path.join(train_folder, file))
    
    for file in validation_files:
        shutil.copy(os.path.join(source_folder, file), os.path.join(validation_folder, file))

# Membagi data untuk folder CAT
split_data(cat_dir, os.path.join(train_dir, 'CAT'), os.path.join(validation_dir, 'CAT'))

# Membagi data untuk folder DOG
split_data(dog_dir, os.path.join(train_dir, 'DOG'), os.path.join(validation_dir, 'DOG'))

print("Data telah dibagi menjadi train dan validation.")
# Out:
# Data telah dibagi menjadi train dan validation.

# %% [markdown]
# # Preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data Augmentation untuk pelatihan
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normalisasi gambar
)

validation_datagen = ImageDataGenerator(rescale=1./255)  # Normalisasi saja untuk data validasi

train_generator = train_datagen.flow_from_directory(
    'PetImages/train',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    'PetImages/validation',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 24992 images belonging to 2 classes.
# Found 13148 images belonging to 2 classes.

# %% [markdown]
# ## Ploting

# %%
batch = next(train_generator)
images = batch[0] 
labels = batch[1]


fig, axes = plt.subplots(2, 5, figsize=(20, 5))

for i, ax in enumerate(axes.flat):
 
    ax.imshow(images[i]) 
    label = 'dog' if labels[i] == 1 else 'cat'
    ax.set_title(f"Label: {label}")
    ax.axis('off')

plt.show()

# %% [markdown]
# # Modelling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Membangun model CNN
model = Sequential()

model.add(Input(shape=(64, 64, 3)))  # Dimensi input diatur menggunakan Input layer


model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

optimizer = Adam(learning_rate=0.01)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=20,  # Lebih sedikit dari jumlah batch total
    epochs=100,
    validation_data=validation_generator,
    validation_steps=10,
    verbose=1
)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 12s 503ms/step - accuracy: 0.4891 - loss: 0.7451 - val_accuracy: 0.5437 - val_loss: 0.6879
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 457ms/step - accuracy: 0.5534 - loss: 0.6880 - val_accuracy: 0.5906 - val_loss: 0.6825
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 421ms/step - accuracy: 0.4792 - loss: 0.7005 - val_accuracy: 0.5375 - val_loss: 0.6902
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 382ms/step - accuracy: 0.5469 - loss: 0.6902 - val_accuracy: 0.5500 - val_loss: 0.6719
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.5691 - loss: 0.6834 - val_accuracy: 0.6281 - val_loss: 0.6560
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.5690 - loss: 0.6682
# C:\Users\ASUS\anaconda3\Lib\site-packages\PIL\TiffImagePlugin.py:900: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 334ms/step - accuracy: 0.5696 - loss: 0.6683 - val_accuracy: 0.6469 - val_loss: 0.6465
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 294ms/step - accuracy: 0.6085 - loss: 0.6632 - val_accuracy: 0.6062 - val_loss: 0.6657
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 305ms/step - accuracy: 0.5693 - loss: 0.6817 - val_accuracy: 0.6625 - val_loss: 0.6489
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 0.6040 - loss: 0.6544 - val_accuracy: 0.5781 - val_loss: 0.6978
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 289ms/step - accuracy: 0.6259 - loss: 0.6536 - val_accuracy: 0.6500 - val_loss: 0.6458
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 303ms/step - accuracy: 0.6551 - loss: 0.6452 - val_accuracy: 0.6906 - val_loss: 0.6222
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 295ms/step - accuracy: 0.7244 - loss: 0.5898 - val_accuracy: 0.6812 - val_loss: 0.5960
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.6621 - loss: 0.6288 - val_accuracy: 0.6969 - val_loss: 0.5744
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 292ms/step - accuracy: 0.6415 - loss: 0.6312 - val_accuracy: 0.7250 - val_loss: 0.5700
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - accuracy: 0.6830 - loss: 0.6212 - val_accuracy: 0.6562 - val_loss: 0.6094
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 260ms/step - accuracy: 0.6982 - loss: 0.5925 - val_accuracy: 0.6656 - val_loss: 0.5843
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 295ms/step - accuracy: 0.6701 - loss: 0.5846 - val_accuracy: 0.7094 - val_loss: 0.5571
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - accuracy: 0.7085 - loss: 0.5753 - val_accuracy: 0.7344 - val_loss: 0.5291
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.6953 - loss: 0.5753 - val_accuracy: 0.7125 - val_loss: 0.5312
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 254ms/step - accuracy: 0.7124 - loss: 0.5723 - val_accuracy: 0.7188 - val_loss: 0.5423
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 258ms/step - accuracy: 0.7484 - loss: 0.5404 - val_accuracy: 0.7719 - val_loss: 0.4888
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - accuracy: 0.6918 - loss: 0.5784 - val_accuracy: 0.7281 - val_loss: 0.5477
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - accuracy: 0.7075 - loss: 0.5743 - val_accuracy: 0.7031 - val_loss: 0.5669
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - accuracy: 0.7619 - loss: 0.5400 - val_accuracy: 0.7312 - val_loss: 0.5277
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - accuracy: 0.7153 - loss: 0.5573 - val_accuracy: 0.7250 - val_loss: 0.5403
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - accuracy: 0.7169 - loss: 0.5745 - val_accuracy: 0.6562 - val_loss: 0.5977
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.7253 - loss: 0.5333 - val_accuracy: 0.7781 - val_loss: 0.4894
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - accuracy: 0.7695 - loss: 0.5242 - val_accuracy: 0.7219 - val_loss: 0.5037
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - accuracy: 0.7331 - loss: 0.5415 - val_accuracy: 0.7469 - val_loss: 0.5082
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.7963 - loss: 0.4851 - val_accuracy: 0.7500 - val_loss: 0.5041
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 229ms/step - accuracy: 0.7470 - loss: 0.5186 - val_accuracy: 0.7625 - val_loss: 0.5262
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - accuracy: 0.7523 - loss: 0.5452 - val_accuracy: 0.7594 - val_loss: 0.5217
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.7574 - loss: 0.5470 - val_accuracy: 0.7594 - val_loss: 0.4949
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - accuracy: 0.7598 - loss: 0.5184 - val_accuracy: 0.7500 - val_loss: 0.5435
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 0.7778 - loss: 0.5077 - val_accuracy: 0.7531 - val_loss: 0.5197
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - accuracy: 0.7270 - loss: 0.5261 - val_accuracy: 0.7344 - val_loss: 0.5115
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - accuracy: 0.8066 - loss: 0.4545 - val_accuracy: 0.7688 - val_loss: 0.4836
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.7812 - loss: 0.4858 - val_accuracy: 0.7719 - val_loss: 0.4700
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.7674 - loss: 0.4835 - val_accuracy: 0.7594 - val_loss: 0.4894
# Epoch 40/100
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8125 - loss: 0.5421
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.8125 - loss: 0.5421 - val_accuracy: 0.7500 - val_loss: 0.5388
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 253ms/step - accuracy: 0.7800 - loss: 0.5300 - val_accuracy: 0.7781 - val_loss: 0.4581
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - accuracy: 0.7347 - loss: 0.5309 - val_accuracy: 0.7594 - val_loss: 0.4886
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - accuracy: 0.7603 - loss: 0.4961 - val_accuracy: 0.8000 - val_loss: 0.4555
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.7470 - loss: 0.5199 - val_accuracy: 0.7688 - val_loss: 0.4848
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - accuracy: 0.7835 - loss: 0.4794 - val_accuracy: 0.7375 - val_loss: 0.5149
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.7382 - loss: 0.4989 - val_accuracy: 0.7531 - val_loss: 0.5412
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.7376 - loss: 0.5077 - val_accuracy: 0.7875 - val_loss: 0.4665
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.7758 - loss: 0.4645 - val_accuracy: 0.7437 - val_loss: 0.4979
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.7384 - loss: 0.5338 - val_accuracy: 0.7969 - val_loss: 0.4356
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.7931 - loss: 0.4610 - val_accuracy: 0.7844 - val_loss: 0.4574
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.7734 - loss: 0.4755 - val_accuracy: 0.8094 - val_loss: 0.4646
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - accuracy: 0.7799 - loss: 0.4810 - val_accuracy: 0.7937 - val_loss: 0.4366
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.7460 - loss: 0.4968 - val_accuracy: 0.7625 - val_loss: 0.4891
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.7742 - loss: 0.4750 - val_accuracy: 0.7156 - val_loss: 0.5613
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.7781 - loss: 0.4763 - val_accuracy: 0.8000 - val_loss: 0.4539
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.7435 - loss: 0.4987 - val_accuracy: 0.8188 - val_loss: 0.3821
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.8215 - loss: 0.4044 - val_accuracy: 0.7719 - val_loss: 0.4352
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.8003 - loss: 0.4326 - val_accuracy: 0.7469 - val_loss: 0.4930
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.7869 - loss: 0.4704 - val_accuracy: 0.7812 - val_loss: 0.4284
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.7871 - loss: 0.4715 - val_accuracy: 0.7750 - val_loss: 0.4535
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.7677 - loss: 0.4735 - val_accuracy: 0.8031 - val_loss: 0.4803
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.7671 - loss: 0.4672 - val_accuracy: 0.7906 - val_loss: 0.4522
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.7768 - loss: 0.4639 - val_accuracy: 0.7937 - val_loss: 0.4337
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - accuracy: 0.7625 - loss: 0.4859 - val_accuracy: 0.7875 - val_loss: 0.4528
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8153 - loss: 0.4379 - val_accuracy: 0.7563 - val_loss: 0.4575
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.7927 - loss: 0.4250 - val_accuracy: 0.8375 - val_loss: 0.3875
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.7974 - loss: 0.4399 - val_accuracy: 0.8031 - val_loss: 0.4208
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.7730 - loss: 0.4581 - val_accuracy: 0.7969 - val_loss: 0.4050
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.7932 - loss: 0.4335 - val_accuracy: 0.7844 - val_loss: 0.4416
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7802 - loss: 0.4309 - val_accuracy: 0.7969 - val_loss: 0.4374
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8020 - loss: 0.4755 - val_accuracy: 0.8094 - val_loss: 0.4523
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.8265 - loss: 0.3837 - val_accuracy: 0.8062 - val_loss: 0.4315
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7999 - loss: 0.4107 - val_accuracy: 0.8031 - val_loss: 0.4306
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7676 - loss: 0.4809 - val_accuracy: 0.8281 - val_loss: 0.3812
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.7863 - loss: 0.4253 - val_accuracy: 0.8188 - val_loss: 0.4234
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8021 - loss: 0.4524 - val_accuracy: 0.8469 - val_loss: 0.3991
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7863 - loss: 0.4472 - val_accuracy: 0.7719 - val_loss: 0.4659
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7468 - loss: 0.4894 - val_accuracy: 0.7969 - val_loss: 0.3975
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.7696 - loss: 0.4714 - val_accuracy: 0.8125 - val_loss: 0.4086
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8438 - loss: 0.3704 - val_accuracy: 0.7969 - val_loss: 0.4454
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.7982 - loss: 0.4279 - val_accuracy: 0.8344 - val_loss: 0.4091
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.8050 - loss: 0.4769 - val_accuracy: 0.8031 - val_loss: 0.4323
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.8136 - loss: 0.4142 - val_accuracy: 0.7937 - val_loss: 0.3937
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8160 - loss: 0.4237 - val_accuracy: 0.8375 - val_loss: 0.3762
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8322 - loss: 0.4180 - val_accuracy: 0.8469 - val_loss: 0.3585
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.8470 - loss: 0.3646 - val_accuracy: 0.8156 - val_loss: 0.3946
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.7626 - loss: 0.4605 - val_accuracy: 0.8281 - val_loss: 0.3886
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8118 - loss: 0.4335 - val_accuracy: 0.8188 - val_loss: 0.4107
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.8361 - loss: 0.3668 - val_accuracy: 0.8156 - val_loss: 0.3965
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7967 - loss: 0.4539 - val_accuracy: 0.7937 - val_loss: 0.4306
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.8152 - loss: 0.3986 - val_accuracy: 0.8469 - val_loss: 0.3439
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.8114 - loss: 0.4159 - val_accuracy: 0.7969 - val_loss: 0.3736
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8302 - loss: 0.3918 - val_accuracy: 0.8469 - val_loss: 0.3674
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8300 - loss: 0.3835 - val_accuracy: 0.8375 - val_loss: 0.3958
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.8127 - loss: 0.4029 - val_accuracy: 0.8406 - val_loss: 0.3669
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.7964 - loss: 0.4291 - val_accuracy: 0.8125 - val_loss: 0.4168
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.8422 - loss: 0.3793 - val_accuracy: 0.8250 - val_loss: 0.4001
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.8192 - loss: 0.4123 - val_accuracy: 0.8219 - val_loss: 0.3953
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.7900 - loss: 0.4506 - val_accuracy: 0.8562 - val_loss: 0.3290
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.8222 - loss: 0.3654 - val_accuracy: 0.8594 - val_loss: 0.3293

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss or accuracy
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


# You can also plot accuracy if you prefer
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluasi

# %%
# Evaluasi model pada data validasi
loss, accuracy = model.evaluate(validation_generator, steps=validation_generator.samples // validation_generator.batch_size)
print(f'Validation Loss: {loss}')
print(f'Validation Accuracy: {accuracy}')
# Out:
# 102/410 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.8423 - loss: 0.3584
# C:\Users\ASUS\anaconda3\Lib\site-packages\PIL\TiffImagePlugin.py:900: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 35s 86ms/step - accuracy: 0.8365 - loss: 0.3666
# Validation Loss: 0.3655029535293579
# Validation Accuracy: 0.8358231782913208

# %% [markdown]
# ## Membuat folder test

# %%
import os
import shutil
import random

source_validation_dir = 'PetImages/validation'
test_dir = 'PetImages/test'

os.makedirs(test_dir, exist_ok=True)


os.makedirs(os.path.join(test_dir, 'CAT'), exist_ok=True)
os.makedirs(os.path.join(test_dir, 'DOG'), exist_ok=True)


def split_data(source_folder, destination_folder, split_ratio=0.2):
    
    for class_name in os.listdir(source_folder):
        class_folder = os.path.join(source_folder, class_name)
        if os.path.isdir(class_folder):
            files = os.listdir(class_folder)
            random.shuffle(files)

            
            num_test_files = int(len(files) * split_ratio)
            test_files = files[:num_test_files]

            
            for file in test_files:
                shutil.move(os.path.join(class_folder, file), os.path.join(destination_folder, class_name, file))


split_data(source_validation_dir, test_dir, split_ratio=0.2)

print("Data successfully split into test and validation.")
# Out:
# Data successfully split into test and validation.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    'PetImages/test',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary',
)

# Evaluasi pada test set
test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Found 7284 images belonging to 2 classes.
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 47s 208ms/step - accuracy: 0.8505 - loss: 0.3490
# Test Loss: 0.35395342111587524
# Test Accuracy: 0.8451266288757324

# %% [markdown]
# # Test Prediksi (Menggunakan gambar dari internet)

# %%
# Menggunakan model untuk prediksi gambar baru
from tensorflow.keras.preprocessing import image
import numpy as np

# Memuat gambar baru
img = image.load_img("D:\\alley-our-bnr.jpg", target_size=(64, 64))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Mengubah dimensi gambar menjadi batch

# Melakukan prediksi
prediction = model.predict(img_array)
print(f"Prediksi: {'Cat' if prediction[0] < 0.5 else 'Dog'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Prediksi: Cat

# %%
img = image.load_img(r"C:\Users\ASUS\OneDrive\Pictures\Golden-Retriever.png", 
                     target_size=(64, 64))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)
print(f"Prediksi: {'Cat' if prediction[0] < 0.5 else 'Dog'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Prediksi: Dog

# %%
img_path = r"C:\Users\ASUS\OneDrive\Pictures\Golden-Retriever.png"
img = image.load_img(img_path, target_size=(64, 64))

img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

plt.imshow(img)
plt.axis('off')
plt.show()

if prediction[0] < 0.5:
    print(f"Your picture is: a Cat")
else:
    print(f"Your picture is: a Dog")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Your picture is: a Dog

# %%
img_path = "D:\\alley-our-bnr.jpg"
img = image.load_img(img_path, target_size=(64, 64))

img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

plt.imshow(img)
plt.axis('off')
plt.show()

if prediction[0] < 0.5:
    print(f"Your picture is: a Cat")
else:
    print(f"Your picture is: a Dog")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Your picture is: a Cat
